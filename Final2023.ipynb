# %% [markdown]
# <a href="https://colab.research.google.com/github/kwansawanth/python_dataviz2023/blob/main/Final2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Final Exam

# %% [markdown]
# รายชื่อสมาชิกภายในกลุ่ม
#
# 1. นางสาวฐาปนี ฟุ้งขจร  633020670-2
# 2. นางสาวขวัญสวรรค์ ทองประเสริฐ  643020498-9
# 3. นายธนบดี ภูชมศรี  643020502-4
# 4. นางสาวนริศรา โยธาจันทร์  643020504-0
# 5. นายปิยพัทธ์ ปานะถึก  643020507-4
# 6. นางสาวกิติลักษณ์ ลาดโฮม  643021260-7

# %% [markdown]
# # เชื่อม Drive เพื่อดึงข้อมูลมาใช้งาน

# %%
from google.colab import drive # เชื่อมบัญชีกับ google drive
drive.mount('/content/drive') # เช็คว่าเชื่อมติดหรือไม่
import pandas as pd
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # เปิด File

# %%
Pos_tran1 = pd.read_csv('/content/drive/MyDrive/final2023/Final2023_DataViz/POS_transactions_20171207-20171219.csv')
Pos_tran2 = pd.read_csv('/content/drive/MyDrive/final2023/Final2023_DataViz/POS_transactions_20190213-20190226.csv')
Pos_tran3= pd.read_csv('/content/drive/MyDrive/final2023/Final2023_DataViz/POS_transactions_20190328-20190410.csv')

# %%
Pos_opr1 = pd.read_csv('/content/drive/MyDrive/final2023/Final2023_DataViz/POS_operator_logs_20171207-20171219.csv')
Pos_opr2 = pd.read_csv('/content/drive/MyDrive/final2023/Final2023_DataViz/POS_operator_logs_20190213-20190226.csv')
Pos_opr3 = pd.read_csv('/content/drive/MyDrive/final2023/Final2023_DataViz/POS_operator_logs_20190328-20190410.csv')

# %%
Pos_tran1
# Out:
#        WorkstationGroupID           TranID        BeginDateTime  \
# 0                       1  171207106022464  2017-12-07T14:23:23
# 1                       1  171207106022465  2017-12-07T14:25:09
# 2                       1  171207106022466  2017-12-07T14:27:28
# 3                       1  171207106022467  2017-12-07T14:28:04
# 4                       1  171207106022468  2017-12-07T14:29:40
# ...                   ...              ...                  ...
# 66858                   1    1712191060847  2017-12-19T11:48:35
# 66859                   1    1712191060848  2017-12-19T11:49:47
# 66860                   1    1712191060849  2017-12-19T11:50:39
# 66861                   1    1712191060851  2017-12-19T11:51:36
# 66862                   1    1712191060853  2017-12-19T11:52:37
#
#                EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# 0      2017-12-07T14:24:36         101        73         33      23    True
# ...

# %% [markdown]
# # ตรวจสอบค่า NULL

# %%
Pos_tran1.isnull()
# Out:
#        WorkstationGroupID  TranID  BeginDateTime  EndDateTime  OperatorID  \
# 0                   False   False          False        False       False
# 1                   False   False          False        False       False
# 2                   False   False          False        False       False
# 3                   False   False          False        False       False
# 4                   False   False          False        False       False
# ...                   ...     ...            ...          ...         ...
# 66858               False   False          False        False       False
# 66859               False   False          False        False       False
# 66860               False   False          False        False       False
# 66861               False   False          False        False       False
# 66862               False   False          False        False       False
#
#        TranTime  BreakTime  ArtNum  TNcash  TNcard  Amount
# ...

# %%
Pos_opr1.isnull().any()
# Out:
# WorkstationGroupID    False
# WorkstationID         False
# TranID                False
# BeginDateTime         False
# OperatorID            False
# Items                 False
# dtype: bool

# %%
Pos_opr2.isnull().any()
# Out:
# WorkstationGroupID    False
# WorkstationID         False
# TranID                False
# BeginDateTime         False
# OperatorID            False
# Items                 False
# dtype: bool

# %%
Pos_opr3.isnull().any()
# Out:
# WorkstationGroupID    False
# WorkstationID         False
# TranID                False
# BeginDateTime         False
# OperatorID            False
# Items                 False
# dtype: bool

# %%
Pos_opr1.head()
# Out:
#    WorkstationGroupID  WorkstationID         TranID        BeginDateTime  \
# 0                   8             16  1712071060162  2017-12-07T06:04:01
# 1                   8             15  1712071060152  2017-12-07T06:04:15
# 2                   8             14  1712071060142  2017-12-07T06:05:36
# 3                   8             18  1712071060182  2017-12-07T06:05:41
# 4                   8             17  1712071060172  2017-12-07T06:05:56
#
#    OperatorID           Items
# 0         266  OperatorSignOn
# 1         265  OperatorSignOn
# 2         264  OperatorSignOn
# 3         268  OperatorSignOn
# 4         267  OperatorSignOn

# %%
Pos_opr2.head()
# Out:
#    WorkstationGroupID  WorkstationID         TranID        BeginDateTime  \
# 0                   8             19  1902131060192  2019-02-13T05:37:55
# 1                   8             18  1902131060182  2019-02-13T05:37:55
# 2                   8             17  1902131060172  2019-02-13T05:38:43
# 3                   1              4   190213106042  2019-02-13T07:01:26
# 4                   1              7   190213106072  2019-02-13T07:01:57
#
#    OperatorID           Items
# 0         269  OperatorSignOn
# 1         268  OperatorSignOn
# 2         267  OperatorSignOn
# 3         332  OperatorSignOn
# 4          10  OperatorSignOn

# %%
Pos_opr3.head()
# Out:
#    WorkstationGroupID  WorkstationID         TranID        BeginDateTime  \
# 0                   8             19  1903281060192  2019-03-28T06:08:13
# 1                   8             18  1903281060182  2019-03-28T06:09:13
# 2                   8             17  1903281060172  2019-03-28T06:08:33
# 3                   1              4   190328106042  2019-03-28T07:04:45
# 4                   1              6   190328106062  2019-03-28T07:18:38
#
#    OperatorID           Items
# 0         269  OperatorSignOn
# 1         268  OperatorSignOn
# 2         267  OperatorSignOn
# 3         104  OperatorSignOn
# 4         125  OperatorSignOn

# %%
import pandas as pd

# %%
operator = pd.concat([Pos_opr1, Pos_opr2, Pos_opr3])
operator
# Out:
#       WorkstationGroupID  WorkstationID           TranID        BeginDateTime  \
# 0                      8             16    1712071060162  2017-12-07T06:04:01
# 1                      8             15    1712071060152  2017-12-07T06:04:15
# 2                      8             14    1712071060142  2017-12-07T06:05:36
# 3                      8             18    1712071060182  2017-12-07T06:05:41
# 4                      8             17    1712071060172  2017-12-07T06:05:56
# ...                  ...            ...              ...                  ...
# 4173                   1              3   19041010603798  2019-04-10T21:53:58
# 4174                   1              4  190410106041042  2019-04-10T21:54:30
# 4175                   1              4  190410106041044  2019-04-10T21:55:05
# 4176                   1              5   19041010605515  2019-04-10T22:00:25
# 4177                   1              4  190410106041061  2019-04-10T22:10:57
#
# ...

# %%
operator.isnull().any()
# Out:
# WorkstationGroupID    False
# WorkstationID         False
# TranID                False
# BeginDateTime         False
# OperatorID            False
# Items                 False
# dtype: bool

# %%
transaction = pd.concat([Pos_tran1, Pos_tran2, Pos_tran3])
transaction
# Out:
#        WorkstationGroupID        TranID        BeginDateTime  \
# 0                       1  1.712071e+14  2017-12-07T14:23:23
# 1                       1  1.712071e+14  2017-12-07T14:25:09
# 2                       1  1.712071e+14  2017-12-07T14:27:28
# 3                       1  1.712071e+14  2017-12-07T14:28:04
# 4                       1  1.712071e+14  2017-12-07T14:29:40
# ...                   ...           ...                  ...
# 49335                   1  1.904101e+14  2019-04-10T14:05:20
# 49336                   1  1.904101e+14  2019-04-10T14:06:39
# 49337                   1  1.904101e+14  2019-04-10T14:07:51
# 49338                   1  1.904101e+14  2019-04-10T14:09:46
# 49339                   1  1.904101e+14  2019-04-10T14:10:29
#
#                EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# 0      2017-12-07T14:24:36         101        73         33      23    True
# 1      2017-12-07T14:27:00         101       111         28      29    True
# ...

# %%
transaction['TranID']
# Out:
# 0        1.712071e+14
# 1        1.712071e+14
# 2        1.712071e+14
# 3        1.712071e+14
# 4        1.712071e+14
#              ...
# 49335    1.904101e+14
# 49336    1.904101e+14
# 49337    1.904101e+14
# 49338    1.904101e+14
# 49339    1.904101e+14
# Name: TranID, Length: 163269, dtype: float64

# %%
transaction.isnull().any()
# Out:
# WorkstationGroupID    False
# TranID                False
# BeginDateTime         False
# EndDateTime           False
# OperatorID            False
# TranTime              False
# BreakTime             False
# ArtNum                False
# TNcash                False
# TNcard                False
# Amount                False
# dtype: bool

# %%
bool_series1 = transaction.duplicated(subset='TranID')
# passing NOT of bool series to see unique values only (ดูเฉพาะค่าที่ไม่ซ้ำ)
tr= transaction[~bool_series1]
# displaying data (ดูผลลัพธ์)
tr1 = tr.reset_index() # .reset_index() เพื่อจัดเรียงให้เป็นระเบียบ
tr1
# Out:
#         index  WorkstationGroupID        TranID        BeginDateTime  \
# 0           0                   1  1.712071e+14  2017-12-07T14:23:23
# 1           1                   1  1.712071e+14  2017-12-07T14:25:09
# 2           2                   1  1.712071e+14  2017-12-07T14:27:28
# 3           3                   1  1.712071e+14  2017-12-07T14:28:04
# 4           4                   1  1.712071e+14  2017-12-07T14:29:40
# ...       ...                 ...           ...                  ...
# 126954  48551                   1  1.904021e+11  2019-04-02T11:08:22
# 126955  48552                   1  1.904021e+11  2019-04-02T11:09:30
# 126956  48553                   1  1.904021e+11  2019-04-02T11:10:21
# 126957  48554                   1  1.904021e+11  2019-04-02T11:11:13
# 126958  48555                   1  1.904021e+11  2019-04-02T11:11:54
#
#                 EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# ...

# %%
bool_series = operator.duplicated(subset='TranID')
# passing NOT of bool series to see unique values only (ดูเฉพาะค่าที่ไม่ซ้ำ)
op = operator[~bool_series]
# displaying data (ดูผลลัพธ์)
op1 = op.reset_index() # .reset_index() เพื่อจัดเรียงให้เป็นระเบียบ
op1
# Out:
#        index  WorkstationGroupID  WorkstationID           TranID  \
# 0          0                   8             16    1712071060162
# 1          1                   8             15    1712071060152
# 2          2                   8             14    1712071060142
# 3          3                   8             18    1712071060182
# 4          4                   8             17    1712071060172
# ...      ...                 ...            ...              ...
# 14069   4173                   1              3   19041010603798
# 14070   4174                   1              4  190410106041042
# 14071   4175                   1              4  190410106041044
# 14072   4176                   1              5   19041010605515
# 14073   4177                   1              4  190410106041061
#
#              BeginDateTime  OperatorID            Items
# 0      2017-12-07T06:04:01         266   OperatorSignOn
# 1      2017-12-07T06:04:15         265   OperatorSignOn
# ...

# %%
import datetime #import datetime เพื่อใช้

# %%
tr1['BeginDateTime'] #check value ใน BeginDateTime
# Out:
# 0         2017-12-07T14-23-23
# 1         2017-12-07T14-25-09
# 2         2017-12-07T14-27-28
# 3         2017-12-07T14-28-04
# 4         2017-12-07T14-29-40
#                  ...
# 126954    2019-04-02T11-08-22
# 126955    2019-04-02T11-09-30
# 126956    2019-04-02T11-10-21
# 126957    2019-04-02T11-11-13
# 126958    2019-04-02T11-11-54
# Name: BeginDateTime, Length: 126959, dtype: object

# %% [markdown]
# #นำไปทำDashboard

# %%
import datetime as dt

# %%
tr1
# Out:
#         index  WorkstationGroupID        TranID        BeginDateTime  \
# 0           0                   1  1.712071e+14  2017-12-07T14-23-23
# 1           1                   1  1.712071e+14  2017-12-07T14-25-09
# 2           2                   1  1.712071e+14  2017-12-07T14-27-28
# 3           3                   1  1.712071e+14  2017-12-07T14-28-04
# 4           4                   1  1.712071e+14  2017-12-07T14-29-40
# ...       ...                 ...           ...                  ...
# 126954  48551                   1  1.904021e+11  2019-04-02T11-08-22
# 126955  48552                   1  1.904021e+11  2019-04-02T11-09-30
# 126956  48553                   1  1.904021e+11  2019-04-02T11-10-21
# 126957  48554                   1  1.904021e+11  2019-04-02T11-11-13
# 126958  48555                   1  1.904021e+11  2019-04-02T11-11-54
#
#                 EndDateTime  OperatorID  TranTime  BreakTime  ArtNum TNcash  \
# ...

# %%
tr1.loc[tr1['TNcard']== 'Service', "TNcard"] = 'Cash'
tr1

# %%
tr1['Date'] = tr['BeginDateTime'].dt.date #split date and time

# %%
tr1.loc[tr1['WorkstationGroupID']== 1, "WorkstationGroupID"] = 'Service' #เปลี่ยน จากID 1 service
tr1
# Out:
#         index WorkstationGroupID        TranID        BeginDateTime  \
# 0           0            Service  1.712071e+14  2017-12-07T14:23:23
# 1           1            Service  1.712071e+14  2017-12-07T14:25:09
# 2           2            Service  1.712071e+14  2017-12-07T14:27:28
# 3           3            Service  1.712071e+14  2017-12-07T14:28:04
# 4           4            Service  1.712071e+14  2017-12-07T14:29:40
# ...       ...                ...           ...                  ...
# 126954  48551            Service  1.904021e+11  2019-04-02T11:08:22
# 126955  48552            Service  1.904021e+11  2019-04-02T11:09:30
# 126956  48553            Service  1.904021e+11  2019-04-02T11:10:21
# 126957  48554            Service  1.904021e+11  2019-04-02T11:11:13
# 126958  48555            Service  1.904021e+11  2019-04-02T11:11:54
#
#                 EndDateTime  OperatorID  TranTime  BreakTime  ArtNum TNcash  \
# ...

# %%
tr1.loc[tr1['WorkstationGroupID'] == 8, "WorkstationGroupID"] = 'Self-Service' #เปลี่ยน จากID 8 Self-service
tr1[tr1['WorkstationGroupID'] == 'Self-Service']
# Out:
#         index WorkstationGroupID        TranID        BeginDateTime  \
# 0           0            Service  1.712071e+14  2017-12-07T14:23:23
# 1           1            Service  1.712071e+14  2017-12-07T14:25:09
# 2           2            Service  1.712071e+14  2017-12-07T14:27:28
# 3           3            Service  1.712071e+14  2017-12-07T14:28:04
# 4           4            Service  1.712071e+14  2017-12-07T14:29:40
# ...       ...                ...           ...                  ...
# 126954  48551            Service  1.904021e+11  2019-04-02T11:08:22
# 126955  48552            Service  1.904021e+11  2019-04-02T11:09:30
# 126956  48553            Service  1.904021e+11  2019-04-02T11:10:21
# 126957  48554            Service  1.904021e+11  2019-04-02T11:11:13
# 126958  48555            Service  1.904021e+11  2019-04-02T11:11:54
#
#                 EndDateTime  OperatorID  TranTime  BreakTime  ArtNum TNcash  \
# ...

# %%
tr1
# Out:
#         index WorkstationGroupID        TranID        BeginDateTime  \
# 0           0            Service  1.712071e+14  2017-12-07T14:23:23
# 1           1            Service  1.712071e+14  2017-12-07T14:25:09
# 2           2            Service  1.712071e+14  2017-12-07T14:27:28
# 3           3            Service  1.712071e+14  2017-12-07T14:28:04
# 4           4            Service  1.712071e+14  2017-12-07T14:29:40
# ...       ...                ...           ...                  ...
# 126954  48551            Service  1.904021e+11  2019-04-02T11:08:22
# 126955  48552            Service  1.904021e+11  2019-04-02T11:09:30
# 126956  48553            Service  1.904021e+11  2019-04-02T11:10:21
# 126957  48554            Service  1.904021e+11  2019-04-02T11:11:13
# 126958  48555            Service  1.904021e+11  2019-04-02T11:11:54
#
#                 EndDateTime  OperatorID  TranTime  BreakTime  ArtNum TNcash  \
# ...

# %%
tr1[tr1['WorkstationGroupID'] == 'Self-Service'] #check self-service ว่าเปลี่ยนแล้ว
# Out:
#         index WorkstationGroupID        TranID        BeginDateTime  \
# 45410   45410       Self-Service  1.712071e+12  2017-12-07T07:00:41
# 45411   45411       Self-Service  1.712071e+12  2017-12-07T07:08:01
# 45412   45412       Self-Service  1.712071e+12  2017-12-07T07:11:31
# 45413   45413       Self-Service  1.712071e+13  2017-12-07T07:15:53
# 45414   45414       Self-Service  1.712071e+13  2017-12-07T07:18:24
# ...       ...                ...           ...                  ...
# 98404   31628       Self-Service  1.902261e+14  2019-02-26T21:01:45
# 98405   31629       Self-Service  1.902261e+14  2019-02-26T21:08:29
# 126884  31889       Self-Service  1.903311e+14  2019-03-31T13:04:30
# 126885  32100       Self-Service  1.904011e+14  2019-04-01T11:36:32
# 126886  32355       Self-Service  1.904021e+14  2019-04-02T11:15:35
#
#                 EndDateTime  OperatorID  TranTime  BreakTime  ArtNum TNcash  \
# ...

# %%
tr1.loc[tr1['TNcash']== True, "TNcash"] = 'Cash'. #เปลี่ยน True เป็น cash
tr1
# Out:
#         index WorkstationGroupID        TranID        BeginDateTime  \
# 0           0            Service  1.712071e+14  2017-12-07T14:23:23
# 1           1            Service  1.712071e+14  2017-12-07T14:25:09
# 2           2            Service  1.712071e+14  2017-12-07T14:27:28
# 3           3            Service  1.712071e+14  2017-12-07T14:28:04
# 4           4            Service  1.712071e+14  2017-12-07T14:29:40
# ...       ...                ...           ...                  ...
# 126954  48551            Service  1.904021e+11  2019-04-02T11:08:22
# 126955  48552            Service  1.904021e+11  2019-04-02T11:09:30
# 126956  48553            Service  1.904021e+11  2019-04-02T11:10:21
# 126957  48554            Service  1.904021e+11  2019-04-02T11:11:13
# 126958  48555            Service  1.904021e+11  2019-04-02T11:11:54
#
#                 EndDateTime  OperatorID  TranTime  BreakTime  ArtNum TNcash  \
# ...

# %%
tr1
# Out:
#         index WorkstationGroupID        TranID        BeginDateTime  \
# 0           0            Service  1.712071e+14  2017-12-07T14:23:23
# 1           1            Service  1.712071e+14  2017-12-07T14:25:09
# 2           2            Service  1.712071e+14  2017-12-07T14:27:28
# 3           3            Service  1.712071e+14  2017-12-07T14:28:04
# 4           4            Service  1.712071e+14  2017-12-07T14:29:40
# ...       ...                ...           ...                  ...
# 126954  48551            Service  1.904021e+11  2019-04-02T11:08:22
# 126955  48552            Service  1.904021e+11  2019-04-02T11:09:30
# 126956  48553            Service  1.904021e+11  2019-04-02T11:10:21
# 126957  48554            Service  1.904021e+11  2019-04-02T11:11:13
# 126958  48555            Service  1.904021e+11  2019-04-02T11:11:54
#
#                 EndDateTime  OperatorID  TranTime  BreakTime  ArtNum TNcash  \
# ...

# %%
tr1.to_csv('tran_full.csv', index=False)  #เอาtr1เข้า

# %% [markdown]
# #Testcode

# %%
for_test1 = tr1[['TranID','Date','TNcash','TNcard','Amount']]
for_test1.to_csv('grouby.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-177-641b59431126> in <cell line: 1>()
# ----> 1 for_test1 = tr1[['TranID','Date','TNcash','TNcard','Amount']]
#       2 for_test1.to_csv('grouby.csv', index=False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# -> 6070         self._raise_if_missing(keyarr, indexer, axis_name)
#    6071
# ...

# %%
for_test1.to_csv('grouby', index=False)

# %%
for_test1 = tr1[['TranID','Date','TNcash','TNcard','Amount']]
for_test1.groupby('TNcash').count().reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-179-7d51a5abfdbf> in <cell line: 1>()
# ----> 1 for_test1 = tr1[['TranID','Date','TNcash','TNcard','Amount']]
#       2 for_test1.groupby('TNcash').count().reset_index()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# -> 6070         self._raise_if_missing(keyarr, indexer, axis_name)
#    6071
# ...

# %%
for_test1.groupby('TNcard').count().reset_index()

# %%
group_TNcard = tr1[['TNcard','Amount']].groupby('TNcard').count().reset_index()
group_TNcard

# %%
group_TNcash = tr1[['TNcash','Amount']].groupby('TNcash').count().reset_index()
group_TNcash

# %%
group_TNcash.to_csv('Cash1.csv', index=False)

# %%
p_1=pd.concat([group_TNcash,group_TNcard])
p_1

# %%
group_TNcash[['TNcard','Amount_card']] = group_TNcard
group_TNcard

# %%
tr1[['TNcard']]

# %%
import numpy as np

# %%
tr1['TNcard'] = tr1['TNcard'].replace({True: 'Card'})

# %%
data = tr1['TNcard'].replace(to_replace=['True'],
    value='Card',
    inplace=True)

# %%
tr1['TNcard'].replace(to_replace=['False'],
    value='Nocard',
    inplace=True)

# %%
tr1["TNcard"].replace(["False"], "Nocard", inplace=True)

# %%
tr1.loc[tr1['TNcash']== 'True', "TNcash"] = "Cash"
tr1
# Out:
#         index  WorkstationGroupID        TranID        BeginDateTime  \
# 0           0                   1  1.712071e+14  2017-12-07T14-23-23
# 1           1                   1  1.712071e+14  2017-12-07T14-25-09
# 2           2                   1  1.712071e+14  2017-12-07T14-27-28
# 3           3                   1  1.712071e+14  2017-12-07T14-28-04
# 4           4                   1  1.712071e+14  2017-12-07T14-29-40
# ...       ...                 ...           ...                  ...
# 126954  48551                   1  1.904021e+11  2019-04-02T11-08-22
# 126955  48552                   1  1.904021e+11  2019-04-02T11-09-30
# 126956  48553                   1  1.904021e+11  2019-04-02T11-10-21
# 126957  48554                   1  1.904021e+11  2019-04-02T11-11-13
# 126958  48555                   1  1.904021e+11  2019-04-02T11-11-54
#
#                 EndDateTime  OperatorID  TranTime  BreakTime  ArtNum TNcash  \
# ...

# %%
tr1.to_csv('Cashh.csv', index=False)
